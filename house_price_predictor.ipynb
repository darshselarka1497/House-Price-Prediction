# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques

# %%
# !ls

# %%
#Build the dataframe for train data
train=pd.read_csv('train.csv',encoding='utf-8')
train.drop(['Id'], axis=1)
train_numerical = train.select_dtypes(exclude=['object'])
train_numerical.fillna(0,inplace = True)
train_categoric = train.select_dtypes(include=['object'])
train_categoric.fillna('NONE',inplace = True)
train = train_numerical.merge(train_categoric, left_index = True, right_index = True)
train.head()

# %%
from sklearn.ensemble import IsolationForest
clf = IsolationForest(max_samples = 100, random_state = 42)
clf.fit(train_numerical)
y_noano = clf.predict(train_numerical)
y_noano = pd.DataFrame(y_noano, columns = ['Top'])
y_noano[y_noano['Top'] == 1].index.values
train_numerical = train_numerical.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_numerical.reset_index(drop = True, inplace = True)
train_categoric = train_categoric.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_categoric.reset_index(drop = True, inplace = True)
train = train.iloc[y_noano[y_noano['Top'] == 1].index.values]
train.reset_index(drop = True, inplace = True)

# %%
col_train_num = list(train_numerical.columns)
col_train_num_bis = list(train_numerical.columns)
col_train_cat = list(train_categoric.columns)
col_train_num_bis.remove('SalePrice')
mat_train = np.matrix(train_numerical)
mat_new = np.matrix(train_numerical.drop('SalePrice',axis = 1))
mat_y = np.array(train.SalePrice)
prepro_y = MinMaxScaler()
prepro_y.fit(mat_y.reshape(1227,1))
prepro = MinMaxScaler()
prepro.fit(mat_train)
prepro_test = MinMaxScaler()
prepro_test.fit(mat_new)
train_num_scale = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)
train[col_train_num] = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
COLUMNS = col_train_num
FEATURES = col_train_num_bis
LABEL = "SalePrice"
FEATURES_CAT = col_train_cat
engineered_features = []
for continuous_feature in FEATURES:
    engineered_features.append(
        tf.contrib.layers.real_valued_column(continuous_feature))
for categorical_feature in FEATURES_CAT:
    sparse_column = tf.contrib.layers.sparse_column_with_hash_bucket(
        categorical_feature, hash_bucket_size=1000)
engineered_features.append(tf.contrib.layers.embedding_column(sparse_id_column=sparse_column, dimension=16,combiner="sum"))
# Build the training set and the prediction set
training_set = train[FEATURES + FEATURES_CAT]
prediction_set = train.SalePrice
# Split the train and prediction sets into test train sets
x_train, x_test, y_train, y_test = train_test_split(training_set[FEATURES + FEATURES_CAT] ,
                                                    prediction_set, test_size=0.2, random_state=42)
y_train = pd.DataFrame(y_train, columns = [LABEL])
training_set = pd.DataFrame(x_train, columns = FEATURES + FEATURES_CAT).merge(y_train, left_index = True, right_index = True)
y_test = pd.DataFrame(y_test, columns = [LABEL])
testing_set = pd.DataFrame(x_test, columns = FEATURES + FEATURES_CAT).merge(y_test, left_index = True, right_index = True)

training_set[FEATURES_CAT] = training_set[FEATURES_CAT].applymap(str)
testing_set[FEATURES_CAT] = testing_set[FEATURES_CAT].applymap(str)
def input_fn_new(data_set, training = True):
    continuous_cols = {k: tf.constant(data_set[k].values) for k in FEATURES}
    
    categorical_cols = {k: tf.SparseTensor(
        indices=[[i, 0] for i in range(data_set[k].size)], values = data_set[k].values, dense_shape = [data_set[k].size, 1]) for k in FEATURES_CAT}
# Combines the dictionaries of the categorical and continuous features
    feature_cols = dict(list(continuous_cols.items()) + list(categorical_cols.items()))
    
    if training == True:
        # Converts the label column into a constant Tensor.
        label = tf.constant(data_set[LABEL].values)
# Outputs the feature columns and labels
        return feature_cols, label
    
    return feature_cols
# Builds the Model Framework
regressor = tf.contrib.learn.DNNRegressor(feature_columns = engineered_features, 
                                          activation_fn = tf.nn.relu, hidden_units=[250, 100, 50])
categorical_cols = {k: tf.SparseTensor(indices=[[i, 0] for i in range(training_set[k].size)], values = training_set[k].values, dense_shape = [training_set[k].size, 1]) for k in FEATURES_CAT}

regressor.fit(input_fn = lambda: input_fn_new(training_set) , steps=10000)


import matplotlib.pyplot as plt
import matplotlib
ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
loss_score = ev["loss"]
print("Final Loss on the testing set: {0:f}".format(loss_score))
import matplotlib.pyplot as plt
import matplotlib
import itertools
ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
loss_score = ev["loss"]
print("Final Loss on the testing set: {0:f}".format(loss_score))
reality = pd.DataFrame(prepro.inverse_transform(testing_set.select_dtypes(exclude=['object'])), columns = [COLUMNS]).SalePrice
y = regressor.predict(input_fn=lambda: input_fn_new(testing_set))
predictions = list(itertools.islice(y, testing_set.shape[0]))
predictions = pd.DataFrame(prepro_y.inverse_transform(np.array(predictions).reshape(263,1)))
matplotlib.rc('xtick', labelsize=30) 
matplotlib.rc('ytick', labelsize=30)
fig, ax = plt.subplots(figsize=(15, 12))
plt.style.use('ggplot')
plt.plot(predictions.values, reality.values, 'ro')
plt.xlabel('Predictions', fontsize = 30)
plt.ylabel('Reality', fontsize = 30)
plt.title('Predictions x Reality on dataset Test', fontsize = 30)
ax.plot([reality.min(), reality.max()], [reality.min(), reality.max()], 'k--', lw=4)
plt.show()
# Out:
# WARNING:tensorflow:The default stddev value of initializer was changed from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" in core implementation (tf.feature_column.embedding_column).
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpwskcxwvp
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f49d47c7a90>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpwskcxwvp', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpwskcxwvp/model.ckpt.
# INFO:tensorflow:loss = 0.26323628, step = 1
# INFO:tensorflow:global_step/sec: 83.9573
# INFO:tensorflow:loss = 0.0030941314, step = 101 (1.193 sec)
# INFO:tensorflow:global_step/sec: 90.3668
# INFO:tensorflow:loss = 0.0026154947, step = 201 (1.111 sec)
# INFO:tensorflow:global_step/sec: 89.6762
# INFO:tensorflow:loss = 0.002428526, step = 301 (1.110 sec)
# INFO:tensorflow:global_step/sec: 88.8708
# INFO:tensorflow:loss = 0.0022902177, step = 401 (1.126 sec)
# INFO:tensorflow:global_step/sec: 92.5413
# INFO:tensorflow:loss = 0.0023544615, step = 501 (1.081 sec)
# INFO:tensorflow:global_step/sec: 92.0745
# INFO:tensorflow:loss = 0.002188754, step = 601 (1.085 sec)
# INFO:tensorflow:global_step/sec: 92.9331
# INFO:tensorflow:loss = 0.002092445, step = 701 (1.077 sec)
# INFO:tensorflow:global_step/sec: 91.3147
# INFO:tensorflow:loss = 0.0020537411, step = 801 (1.094 sec)
# INFO:tensorflow:global_step/sec: 91.6148
# INFO:tensorflow:loss = 0.001962701, step = 901 (1.092 sec)
# INFO:tensorflow:global_step/sec: 91.2981
# INFO:tensorflow:loss = 0.0019060215, step = 1001 (1.095 sec)
# INFO:tensorflow:global_step/sec: 91.0296
# INFO:tensorflow:loss = 0.001844486, step = 1101 (1.100 sec)
# INFO:tensorflow:global_step/sec: 91.1601
# INFO:tensorflow:loss = 0.0018246046, step = 1201 (1.095 sec)
# INFO:tensorflow:global_step/sec: 89.9857
# INFO:tensorflow:loss = 0.0017842542, step = 1301 (1.114 sec)
# INFO:tensorflow:global_step/sec: 92.6199
# INFO:tensorflow:loss = 0.0017482663, step = 1401 (1.079 sec)
# INFO:tensorflow:global_step/sec: 93.6992
# INFO:tensorflow:loss = 0.0016691997, step = 1501 (1.071 sec)
# INFO:tensorflow:global_step/sec: 92.0258
# INFO:tensorflow:loss = 0.0016416706, step = 1601 (1.080 sec)
# INFO:tensorflow:global_step/sec: 91.922
# INFO:tensorflow:loss = 0.0016508858, step = 1701 (1.089 sec)
# INFO:tensorflow:global_step/sec: 89.9119
# INFO:tensorflow:loss = 0.0015944378, step = 1801 (1.113 sec)
# INFO:tensorflow:global_step/sec: 92.4775
# INFO:tensorflow:loss = 0.001532414, step = 1901 (1.080 sec)
# INFO:tensorflow:global_step/sec: 93.4299
# INFO:tensorflow:loss = 0.0015200104, step = 2001 (1.071 sec)
# INFO:tensorflow:global_step/sec: 93.0564
# INFO:tensorflow:loss = 0.0015300065, step = 2101 (1.074 sec)
# INFO:tensorflow:global_step/sec: 91.7495
# INFO:tensorflow:loss = 0.0014844252, step = 2201 (1.091 sec)
# INFO:tensorflow:global_step/sec: 93.649
# INFO:tensorflow:loss = 0.0014943464, step = 2301 (1.070 sec)
# INFO:tensorflow:global_step/sec: 90.9358
# INFO:tensorflow:loss = 0.0014418004, step = 2401 (1.097 sec)
# INFO:tensorflow:global_step/sec: 91.6176
# INFO:tensorflow:loss = 0.0013957045, step = 2501 (1.091 sec)
# INFO:tensorflow:global_step/sec: 92.682
# INFO:tensorflow:loss = 0.0014010994, step = 2601 (1.079 sec)
# INFO:tensorflow:global_step/sec: 92.7447
# INFO:tensorflow:loss = 0.0013820056, step = 2701 (1.079 sec)
# INFO:tensorflow:global_step/sec: 91.9894
# INFO:tensorflow:loss = 0.0013686517, step = 2801 (1.089 sec)
# INFO:tensorflow:global_step/sec: 93.6021
# INFO:tensorflow:loss = 0.0013236873, step = 2901 (1.065 sec)
# INFO:tensorflow:global_step/sec: 93.4668
# INFO:tensorflow:loss = 0.0012944597, step = 3001 (1.070 sec)
# INFO:tensorflow:global_step/sec: 93.1134
# INFO:tensorflow:loss = 0.0013058549, step = 3101 (1.074 sec)
# INFO:tensorflow:global_step/sec: 91.4588
# INFO:tensorflow:loss = 0.0013177284, step = 3201 (1.093 sec)
# INFO:tensorflow:global_step/sec: 89.8144
# INFO:tensorflow:loss = 0.0013136177, step = 3301 (1.114 sec)
# INFO:tensorflow:global_step/sec: 93.2396
# INFO:tensorflow:loss = 0.0012302117, step = 3401 (1.072 sec)
# INFO:tensorflow:global_step/sec: 93.2656
# INFO:tensorflow:loss = 0.0012367733, step = 3501 (1.074 sec)
# INFO:tensorflow:global_step/sec: 93.9512
# INFO:tensorflow:loss = 0.0012873475, step = 3601 (1.063 sec)
# INFO:tensorflow:global_step/sec: 93.6837
# INFO:tensorflow:loss = 0.0012589353, step = 3701 (1.068 sec)
# INFO:tensorflow:global_step/sec: 94.1955
# INFO:tensorflow:loss = 0.0011646937, step = 3801 (1.061 sec)
# INFO:tensorflow:global_step/sec: 97.6393
# INFO:tensorflow:loss = 0.0012150086, step = 3901 (1.025 sec)
# INFO:tensorflow:global_step/sec: 98.4043
# INFO:tensorflow:loss = 0.001247361, step = 4001 (1.021 sec)
# INFO:tensorflow:global_step/sec: 96.3317
# INFO:tensorflow:loss = 0.001174359, step = 4101 (1.034 sec)
# INFO:tensorflow:global_step/sec: 97.7384
# INFO:tensorflow:loss = 0.0011302045, step = 4201 (1.023 sec)
# INFO:tensorflow:global_step/sec: 97.0374
# INFO:tensorflow:loss = 0.0011188088, step = 4301 (1.030 sec)
# INFO:tensorflow:global_step/sec: 97.5552
# INFO:tensorflow:loss = 0.0011748992, step = 4401 (1.025 sec)
# INFO:tensorflow:global_step/sec: 99.8358
# INFO:tensorflow:loss = 0.0011510537, step = 4501 (1.003 sec)
# INFO:tensorflow:global_step/sec: 93.9235
# INFO:tensorflow:loss = 0.0010676847, step = 4601 (1.063 sec)
# INFO:tensorflow:global_step/sec: 91.0271
# INFO:tensorflow:loss = 0.0010815316, step = 4701 (1.099 sec)
# INFO:tensorflow:global_step/sec: 90.7501
# INFO:tensorflow:loss = 0.001122126, step = 4801 (1.105 sec)
# INFO:tensorflow:global_step/sec: 91.239
# INFO:tensorflow:loss = 0.0011192326, step = 4901 (1.094 sec)
# INFO:tensorflow:global_step/sec: 87.1217
# INFO:tensorflow:loss = 0.001054678, step = 5001 (1.150 sec)
# INFO:tensorflow:global_step/sec: 89.2922
# INFO:tensorflow:loss = 0.0010232293, step = 5101 (1.118 sec)
# INFO:tensorflow:global_step/sec: 88.077
# INFO:tensorflow:loss = 0.0010597694, step = 5201 (1.140 sec)
# INFO:tensorflow:global_step/sec: 87.8806
# INFO:tensorflow:loss = 0.001106054, step = 5301 (1.133 sec)
# INFO:tensorflow:global_step/sec: 86.8838
# INFO:tensorflow:loss = 0.00096495956, step = 5401 (1.151 sec)
# INFO:tensorflow:global_step/sec: 87.5467
# INFO:tensorflow:loss = 0.0010091425, step = 5501 (1.141 sec)
# INFO:tensorflow:global_step/sec: 91.7692
# INFO:tensorflow:loss = 0.0010657961, step = 5601 (1.093 sec)
# INFO:tensorflow:global_step/sec: 92.437
# INFO:tensorflow:loss = 0.0009870119, step = 5701 (1.079 sec)
# INFO:tensorflow:global_step/sec: 93.2962
# INFO:tensorflow:loss = 0.00092149706, step = 5801 (1.075 sec)
# INFO:tensorflow:global_step/sec: 91.3258
# INFO:tensorflow:loss = 0.0009883152, step = 5901 (1.094 sec)
# INFO:tensorflow:global_step/sec: 91.6667
# INFO:tensorflow:loss = 0.0010037026, step = 6001 (1.091 sec)
# INFO:tensorflow:global_step/sec: 92.5155
# INFO:tensorflow:loss = 0.0009042182, step = 6101 (1.077 sec)
# INFO:tensorflow:global_step/sec: 92.3211
# INFO:tensorflow:loss = 0.0009323358, step = 6201 (1.084 sec)
# INFO:tensorflow:global_step/sec: 91.863
# INFO:tensorflow:loss = 0.0010098459, step = 6301 (1.089 sec)
# INFO:tensorflow:global_step/sec: 93.2179
# INFO:tensorflow:loss = 0.00089428475, step = 6401 (1.073 sec)
# INFO:tensorflow:global_step/sec: 92.3042
# INFO:tensorflow:loss = 0.0008946688, step = 6501 (1.087 sec)
# INFO:tensorflow:global_step/sec: 90.9794
# INFO:tensorflow:loss = 0.0009259763, step = 6601 (1.095 sec)
# INFO:tensorflow:global_step/sec: 92.4087
# INFO:tensorflow:loss = 0.00094757875, step = 6701 (1.082 sec)
# INFO:tensorflow:global_step/sec: 91.0267
# INFO:tensorflow:loss = 0.0008967725, step = 6801 (1.099 sec)
# INFO:tensorflow:global_step/sec: 92.4881
# INFO:tensorflow:loss = 0.0008639314, step = 6901 (1.084 sec)
# INFO:tensorflow:global_step/sec: 93.5472
# INFO:tensorflow:loss = 0.00084482314, step = 7001 (1.070 sec)
# INFO:tensorflow:global_step/sec: 92.7568
# INFO:tensorflow:loss = 0.00086320366, step = 7101 (1.074 sec)
# INFO:tensorflow:global_step/sec: 93.3336
# INFO:tensorflow:loss = 0.0009007271, step = 7201 (1.072 sec)
# INFO:tensorflow:global_step/sec: 93.304
# INFO:tensorflow:loss = 0.0008817146, step = 7301 (1.072 sec)
# INFO:tensorflow:global_step/sec: 92.4938
# INFO:tensorflow:loss = 0.0007964396, step = 7401 (1.082 sec)
# INFO:tensorflow:global_step/sec: 92.9576
# INFO:tensorflow:loss = 0.0008249374, step = 7501 (1.074 sec)
# INFO:tensorflow:global_step/sec: 94.1429
# INFO:tensorflow:loss = 0.000880472, step = 7601 (1.062 sec)
# INFO:tensorflow:global_step/sec: 93.2471
# INFO:tensorflow:loss = 0.00085771515, step = 7701 (1.073 sec)
# INFO:tensorflow:global_step/sec: 91.8297
# INFO:tensorflow:loss = 0.0007761389, step = 7801 (1.089 sec)
# INFO:tensorflow:global_step/sec: 93.1082
# INFO:tensorflow:loss = 0.0007862537, step = 7901 (1.077 sec)
# INFO:tensorflow:global_step/sec: 87.8549
# INFO:tensorflow:loss = 0.0008208114, step = 8001 (1.135 sec)
# INFO:tensorflow:global_step/sec: 84.651
# INFO:tensorflow:loss = 0.00085518975, step = 8101 (1.186 sec)
# INFO:tensorflow:global_step/sec: 86.0904
# INFO:tensorflow:loss = 0.0007632535, step = 8201 (1.158 sec)
# INFO:tensorflow:global_step/sec: 86.6229
# INFO:tensorflow:loss = 0.0007349245, step = 8301 (1.159 sec)
# INFO:tensorflow:global_step/sec: 86.7878
# INFO:tensorflow:loss = 0.0007984361, step = 8401 (1.150 sec)
# INFO:tensorflow:global_step/sec: 91.9934
# INFO:tensorflow:loss = 0.0008128546, step = 8501 (1.086 sec)
# INFO:tensorflow:global_step/sec: 91.6348
# INFO:tensorflow:loss = 0.00074422953, step = 8601 (1.088 sec)
# INFO:tensorflow:global_step/sec: 92.8943
# INFO:tensorflow:loss = 0.0007061821, step = 8701 (1.079 sec)
# INFO:tensorflow:global_step/sec: 92.6499
# INFO:tensorflow:loss = 0.00077726087, step = 8801 (1.078 sec)
# INFO:tensorflow:global_step/sec: 92.5861
# INFO:tensorflow:loss = 0.0007893461, step = 8901 (1.080 sec)
# INFO:tensorflow:global_step/sec: 92.7826
# INFO:tensorflow:loss = 0.00068181846, step = 9001 (1.077 sec)
# INFO:tensorflow:global_step/sec: 91.449
# INFO:tensorflow:loss = 0.0007127279, step = 9101 (1.094 sec)
# INFO:tensorflow:global_step/sec: 90.2217
# INFO:tensorflow:loss = 0.0008039507, step = 9201 (1.109 sec)
# INFO:tensorflow:global_step/sec: 93.4623
# INFO:tensorflow:loss = 0.0007262221, step = 9301 (1.074 sec)
# INFO:tensorflow:global_step/sec: 93.349
# INFO:tensorflow:loss = 0.0006595286, step = 9401 (1.072 sec)
# INFO:tensorflow:global_step/sec: 93.2104
# INFO:tensorflow:loss = 0.00067342655, step = 9501 (1.068 sec)
# INFO:tensorflow:global_step/sec: 92.91
# INFO:tensorflow:loss = 0.0007105624, step = 9601 (1.080 sec)
# INFO:tensorflow:global_step/sec: 93.2126
# INFO:tensorflow:loss = 0.0007323243, step = 9701 (1.069 sec)
# INFO:tensorflow:global_step/sec: 93.7168
# INFO:tensorflow:loss = 0.00074921496, step = 9801 (1.071 sec)
# INFO:tensorflow:global_step/sec: 93.8047
# INFO:tensorflow:loss = 0.0006917705, step = 9901 (1.062 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpwskcxwvp/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0006632979.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Starting evaluation at 2020-02-16T06:22:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpwskcxwvp/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-02-16-06:22:28
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 0.0024770875
# Final Loss on the testing set: 0.002477
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Starting evaluation at 2020-02-16T06:22:29Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpwskcxwvp/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-02-16-06:22:30
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 0.0024770875
# Final Loss on the testing set: 0.002477
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c1e75e6c8182> in <module>()
#      76 loss_score = ev["loss"]
#      77 print("Final Loss on the testing set: {0:f}".format(loss_score))
# ---> 78 reality = pd.DataFrame(prepro.inverse_transform(testing_set.select_dtypes(exclude=['object'])), columns = [COLUMNS]).SalePrice
#      79 y = regressor.predict(input_fn=lambda: input_fn_new(testing_set))
#      80 predictions = list(itertools.islice(y, testing_set.shape[0]))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
# -> 5178                 return self[name]
#    5179             return object.__getattribute__(self, name)
#    5180
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2971                 if self.columns.nlevels > 1:
#    2972                     return self._getitem_multilevel(key)
# -> 2973                 return self._get_item_cache(key)
#    2974
#    2975         # Do we have a slicer (on rows)?
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3268         res = cache.get(item)
#    3269         if res is None:
# -> 3270             values = self._data.get(item)
#    3271             res = self._box_item_values(item, values)
#    3272             cache[item] = res
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in get(self, item)
#     958                         raise ValueError("cannot label index with a null key")
#     959
# --> 960             return self.iget(loc)
#     961         else:
#     962
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in iget(self, i)
#     975         Otherwise return as a ndarray
#     976         """
# --> 977         block = self.blocks[self._blknos[i]]
#     978         values = block.iget(self._blklocs[i])
#     979         if values.ndim != 1:
#
# TypeError: only integer scalar arrays can be converted to a scalar index
